# %%
# !pip install pandas
# !pip install openpyxl
# !pip install numpy
# !pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
#https://en.wikipedia.org/wiki/List_of_counties_in_Colorado
#https://data.colorado.gov/resource/j5pc-4t32.json
#https://www.kaggle.com/datasets/kaggle/sf-salaries

# %%
#dataframe
#excel, csv, json, yaml, xml, python veri yapisi, txt, pdf, html, sql, etc....

# %%
AI=[{'Technology':'DL','Library':'Keras'},
    {'Technology':'ML','Library':'SciPy'},
    {'Technology':'NA','Library':'Netmiko'},
    {'Technology':'RPA','Library':'Tkinter'},
    {'Technology':'DS','Library':'Pandas'},
    {'Technology':'REST API','Library':'Requests'}]
AI
# Out:
# [{'Technology': 'DL', 'Library': 'Keras'},
#  {'Technology': 'ML', 'Library': 'SciPy'},
#  {'Technology': 'NA', 'Library': 'Netmiko'},
#  {'Technology': 'RPA', 'Library': 'Tkinter'},
#  {'Technology': 'DS', 'Library': 'Pandas'},
#  {'Technology': 'REST API', 'Library': 'Requests'}]

# %%
#AI2 ={'isim':['Erdeniz'],'soyisim':['Unvan']}

# %%
#Python veri yapilarindan DF olustururken birden fazla tipte referansa ihtiyac var
#tek tip referans olursa scalar

# %%
import pandas as pd

# %%
DF1= pd.DataFrame(AI)
DF1
# Out:
#   Technology   Library
# 0         DL     Keras
# 1         ML     SciPy
# 2         NA   Netmiko
# 3        RPA   Tkinter
# 4         DS    Pandas
# 5   REST API  Requests

# %%
AI
# Out:
# [{'Technology': 'DL', 'Library': 'Keras'},
#  {'Technology': 'ML', 'Library': 'SciPy'},
#  {'Technology': 'NA', 'Library': 'Netmiko'},
#  {'Technology': 'RPA', 'Library': 'Tkinter'},
#  {'Technology': 'DS', 'Library': 'Pandas'},
#  {'Technology': 'REST API', 'Library': 'Requests'}]

# %%
DF1['Technology']
# Out:
# 0          DL
# 1          ML
# 2          NA
# 3         RPA
# 4          DS
# 5    REST API
# Name: Technology, dtype: object

# %%
DF1['Library']
# Out:
# 0       Keras
# 1       SciPy
# 2     Netmiko
# 3     Tkinter
# 4      Pandas
# 5    Requests
# Name: Library, dtype: object

# %%
DF1.Technology
# Out:
# 0          DL
# 1          ML
# 2          NA
# 3         RPA
# 4          DS
# 5    REST API
# Name: Technology, dtype: object

# %%
DF1.Library
# Out:
# 0       Keras
# 1       SciPy
# 2     Netmiko
# 3     Tkinter
# 4      Pandas
# 5    Requests
# Name: Library, dtype: object

# %%
DF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Technology  6 non-null      object
#  1   Library     6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes

# %%
DF1.shape
# Out:
# (6, 2)

# %%
DF1.Technology[0]
# Out:
# 'DL'

# %%
type(DF1.Technology[0])
# Out:
# str

# %%
import json

# %%
with open('ai1.json','w') as f:
    f.write(json.dumps(AI))

# %%
import os
os.listdir()
# Out:
# ['.config', 'ai1.json', 'sample_data']

# %%
DF2=pd.read_json('ai1.json')
DF2
# Out:
#   Technology   Library
# 0         DL     Keras
# 1         ML     SciPy
# 2         NA   Netmiko
# 3        RPA   Tkinter
# 4         DS    Pandas
# 5   REST API  Requests

# %%
DF3=pd.read_json(json.dumps(AI))
DF3
# Out:
#   Technology   Library
# 0         DL     Keras
# 1         ML     SciPy
# 2         NA   Netmiko
# 3        RPA   Tkinter
# 4         DS    Pandas
# 5   REST API  Requests

# %%
DF1==DF2
# Out:
#    Technology  Library
# 0        True     True
# 1        True     True
# 2        True     True
# 3        True     True
# 4        True     True
# 5        True     True

# %%
DF1
# Out:
#   Technology   Library
# 0         DL     Keras
# 1         ML     SciPy
# 2         NA   Netmiko
# 3        RPA   Tkinter
# 4         DS    Pandas
# 5   REST API  Requests

# %%
DF1.to_excel('ai1.xlsx')

# %%
DF4=pd.read_excel('ai1.xlsx')
DF4
# Out:
#    Unnamed: 0 Technology   Library
# 0           0         DL     Keras
# 1           1         ML     SciPy
# 2           2        NaN   Netmiko
# 3           3        RPA   Tkinter
# 4           4         DS    Pandas
# 5           5   REST API  Requests

# %%
DF1.to_excel('ai2.xlsx',index=False)

# %%
DF5=pd.read_excel('ai2.xlsx')
DF5
# Out:
#   Technology   Library
# 0         DL     Keras
# 1         ML     SciPy
# 2        NaN   Netmiko
# 3        RPA   Tkinter
# 4         DS    Pandas
# 5   REST API  Requests

# %%
DF1.to_csv('ai1.csv',index=False)

# %%
DF6=pd.read_csv('ai1.csv')
DF6
# Out:
#   Technology   Library
# 0         DL     Keras
# 1         ML     SciPy
# 2        NaN   Netmiko
# 3        RPA   Tkinter
# 4         DS    Pandas
# 5   REST API  Requests

# %%
DF7=pd.read_clipboard()
DF7
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# <ipython-input-26-7a10c0d0c370> in <cell line: 1>()
# ----> 1 DF7=pd.read_clipboard()
#       2 DF7
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      43     from pandas.io.parsers import read_csv
#      44
# ---> 45     text = clipboard_get()
#      46
#      47     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     659     global copy, paste
#     660     copy, paste = determine_clipboard()
# --> 661     return paste()
#     662
#     663
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
#     297     class ClipboardUnavailable:
#     298         def __call__(self, *args, **kwargs):
# ...

# %%
DF8=pd.read_clipboard()
DF8
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# <ipython-input-27-d68c027f481f> in <cell line: 1>()
# ----> 1 DF8=pd.read_clipboard()
#       2 DF8
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      43     from pandas.io.parsers import read_csv
#      44
# ---> 45     text = clipboard_get()
#      46
#      47     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     659     global copy, paste
#     660     copy, paste = determine_clipboard()
# --> 661     return paste()
#     662
#     663
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
#     297     class ClipboardUnavailable:
#     298         def __call__(self, *args, **kwargs):
# ...

# %%
url='https://en.wikipedia.org/wiki/List_of_counties_in_Colorado'
DF=pd.read_html(url)
len(DF)
# Out:
# 12

# %%
DF
# Out:
# [                                                   0
#  0  The location of the State of Colorado in the U...
#  1  Adams Alam Arapahoe Arch Baca Bent Boul Bro Ch...
#  2     The 64 counties of the U.S. State of Colorado.,
#                                                     0
#  0  Map this section's coordinates in "Population ...
#  1                       Download coordinates as: KML,
#                 County  FIPS code[5][b] County seat[6][7]     Est.[8]  \
#  0        Adams County                1          Brighton  1902-11-15
#  1      Alamosa County                3           Alamosa  1913-03-08
#  2     Arapahoe County                5         Littleton  1861-11-01
#  3    Archuleta County                7    Pagosa Springs  1885-04-14
#  4         Baca County                9       Springfield  1889-04-16
#  ..                ...              ...               ...         ...
#  59      Summit County              117      Breckenridge  1861-11-01
# ...

# %%
DF[0]
# Out:
#                                                    0
# 0  The location of the State of Colorado in the U...
# 1  Adams Alam Arapahoe Arch Baca Bent Boul Bro Ch...
# 2     The 64 counties of the U.S. State of Colorado.

# %%
DF[2]
# Out:
#                County  FIPS code[5][b] County seat[6][7]     Est.[8]  \
# 0        Adams County                1          Brighton  1902-11-15
# 1      Alamosa County                3           Alamosa  1913-03-08
# 2     Arapahoe County                5         Littleton  1861-11-01
# 3    Archuleta County                7    Pagosa Springs  1885-04-14
# 4         Baca County                9       Springfield  1889-04-16
# ..                ...              ...               ...         ...
# 59      Summit County              117      Breckenridge  1861-11-01
# 60      Teller County              119     Cripple Creek  1899-03-23
# 61  Washington County              121             Akron  1887-02-09
# 62        Weld County              123           Greeley  1861-11-01
# 63        Yuma County              125              Wray  1889-03-15
#
#                                        Formed from[8]  \
# 0                         Split from Arapahoe County.
# ...

# %%
DF[6]
# Out:
#                 County First County Seat
# 0      Arapahoe County       Denver City
# 1       Boulder County      Boulder City
# 2   Clear Creek County             Idaho
# 3      Costilla County     San Miguel[j]
# 4       Douglas County        Frankstown
# 5       El Paso County     Colorado City
# 6       Fremont County        Cañon City
# 7        Gilpin County      Central City
# 8    Guadaloupe County        Guadaloupe
# 9      Huerfano County    Autobees Plaza
# 10    Jefferson County       Golden City
# 11         Lake County          Oro City
# 12      Larimer County          La Porte
# 13         Park County     Tarryall City
# 14       Pueblo County            Pueblo
# 15       Summit County         Parkville
# 16         Weld County               NaN

# %%
#The 13 highest mean elevation counties in the United States
url='https://en.wikipedia.org/wiki/List_of_counties_in_Colorado'
DF9=pd.read_html(url,match='The 13 highest mean elevation counties in the United States')
len(DF9)
# Out:
# 1

# %%
DF9
# Out:
# [    Rank[g]              County      Mean elevation[f]    High point[13]  \
#  0         1         Lake County  11,702.5 feet 3,567 m      Mount Elbert
#  1         2     Hinsdale County    11,300 feet 3,444 m  Uncompahgre Peak
#  2         3      Mineral County    11,116 feet 3,388 m      Phoenix Peak
#  3         4     San Juan County    11,085 feet 3,379 m    Vermilion Peak
#  4         5       Summit County  10,935.5 feet 3,333 m        Grays Peak
#  5         6      Alamosa County  10,928.5 feet 3,331 m       Blanca Peak
#  6         7     Saguache County    10,915 feet 3,327 m     Crestone Peak
#  7         8     Costilla County  10,865.5 feet 3,312 m       Blanca Peak
#  8         9         Park County  10,705.5 feet 3,263 m     Mount Lincoln
#  9        10      Chaffee County    10,661 feet 3,249 m     Mount Harvard
#  10       11  Clear Creek County    10,608 feet 3,233 m        Grays Peak
#  11       12   Rio Grande County    10,402 feet 3,171 m      Bennett Peak
# ...

# %%
DF9[0]
# Out:
#     Rank[g]              County      Mean elevation[f]    High point[13]  \
# 0         1         Lake County  11,702.5 feet 3,567 m      Mount Elbert
# 1         2     Hinsdale County    11,300 feet 3,444 m  Uncompahgre Peak
# 2         3      Mineral County    11,116 feet 3,388 m      Phoenix Peak
# 3         4     San Juan County    11,085 feet 3,379 m    Vermilion Peak
# 4         5       Summit County  10,935.5 feet 3,333 m        Grays Peak
# 5         6      Alamosa County  10,928.5 feet 3,331 m       Blanca Peak
# 6         7     Saguache County    10,915 feet 3,327 m     Crestone Peak
# 7         8     Costilla County  10,865.5 feet 3,312 m       Blanca Peak
# 8         9         Park County  10,705.5 feet 3,263 m     Mount Lincoln
# 9        10      Chaffee County    10,661 feet 3,249 m     Mount Harvard
# 10       11  Clear Creek County    10,608 feet 3,233 m        Grays Peak
# 11       12   Rio Grande County    10,402 feet 3,171 m      Bennett Peak
# ...

# %%
DF9[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank[g]                        13 non-null     int64
#  1   County                         13 non-null     object
#  2   Mean elevation[f]              13 non-null     object
#  3   High point[13]                 13 non-null     object
#  4   Highest elevation[14][13][15]  13 non-null     object
#  5   Low point[15]                  13 non-null     object
#  6   Lowest elevation[15]           13 non-null     object
#  7   Elevation range[h]             13 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 960.0+ bytes

# %%
DF[2]
# Out:
#                County  FIPS code[5][b] County seat[6][7]     Est.[8]  \
# 0        Adams County                1          Brighton  1902-11-15
# 1      Alamosa County                3           Alamosa  1913-03-08
# 2     Arapahoe County                5         Littleton  1861-11-01
# 3    Archuleta County                7    Pagosa Springs  1885-04-14
# 4         Baca County                9       Springfield  1889-04-16
# ..                ...              ...               ...         ...
# 59      Summit County              117      Breckenridge  1861-11-01
# 60      Teller County              119     Cripple Creek  1899-03-23
# 61  Washington County              121             Akron  1887-02-09
# 62        Weld County              123           Greeley  1861-11-01
# 63        Yuma County              125              Wray  1889-03-15
#
#                                        Formed from[8]  \
# 0                         Split from Arapahoe County.
# ...

# %%
DF[2].head()
# Out:
#              County  FIPS code[5][b] County seat[6][7]     Est.[8]  \
# 0      Adams County                1          Brighton  1902-11-15
# 1    Alamosa County                3           Alamosa  1913-03-08
# 2   Arapahoe County                5         Littleton  1861-11-01
# 3  Archuleta County                7    Pagosa Springs  1885-04-14
# 4       Baca County                9       Springfield  1889-04-16
#
#                                       Formed from[8]  \
# 0                        Split from Arapahoe County.
# 1     Split from Costilla County and Conejos County.
# 2  Created as one of the 17 original counties of ...
# 3                         Split from Conejos County.
# 4                      Split from Las Animas County.
#
#                                         Etymology[8]  Population[9]  \
# 0  Named in honor of Alva Adams, the 5th, 10th, a...         527575
# 1  Named for the cottonwood trees which grow alon...          16592
# ...

# %%
DF[2].head(60)
# Out:
#                            County  FIPS code[5][b]    County seat[6][7]  \
# 0                    Adams County                1             Brighton
# 1                  Alamosa County                3              Alamosa
# 2                 Arapahoe County                5            Littleton
# 3                Archuleta County                7       Pagosa Springs
# 4                     Baca County                9          Springfield
# 5                     Bent County               11           Las Animas
# 6                  Boulder County               13              Boulder
# 7   City and County of Broomfield               14           Broomfield
# 8                  Chaffee County               15               Salida
# 9                 Cheyenne County               17       Cheyenne Wells
# 10             Clear Creek County               19           Georgetown
# 11                 Conejos County               21              Conejos
# ...

# %%
DF[2].tail()
# Out:
#                County  FIPS code[5][b] County seat[6][7]     Est.[8]  \
# 59      Summit County              117      Breckenridge  1861-11-01
# 60      Teller County              119     Cripple Creek  1899-03-23
# 61  Washington County              121             Akron  1887-02-09
# 62        Weld County              123           Greeley  1861-11-01
# 63        Yuma County              125              Wray  1889-03-15
#
#                                        Formed from[8]  \
# 59  Created as one of the 17 original counties of ...
# 60           Split from El Paso and Fremont counties.
# 61                            Split from Weld County.
# 62  Created as one of the 17 original counties of ...
# 63                      Split from Washington County.
#
#                                          Etymology[8]  Population[9]  \
# 59  Named for the many high mountain summits in th...          30565
# 60  Named in honor of Henry Moore Teller, a U.S. S...          24857
# ...

# %%
DF[2].tail(60)
# Out:
#                            County  FIPS code[5][b]    County seat[6][7]  \
# 4                     Baca County                9          Springfield
# 5                     Bent County               11           Las Animas
# 6                  Boulder County               13              Boulder
# 7   City and County of Broomfield               14           Broomfield
# 8                  Chaffee County               15               Salida
# 9                 Cheyenne County               17       Cheyenne Wells
# 10             Clear Creek County               19           Georgetown
# 11                 Conejos County               21              Conejos
# 12                Costilla County               23             San Luis
# 13                 Crowley County               25               Ordway
# 14                  Custer County               27           Westcliffe
# 15                   Delta County               29                Delta
# ...

# %%
DF[2].iloc[19:30]
# Out:
#              County  FIPS code[5][b]    County seat[6][7]     Est.[8]  \
# 19     Eagle County               37                Eagle  1883-02-11
# 20   El Paso County               41     Colorado Springs  1861-11-01
# 21    Elbert County               39                Kiowa  1874-02-02
# 22   Fremont County               43           Cañon City  1861-11-01
# 23  Garfield County               45     Glenwood Springs  1883-02-10
# 24    Gilpin County               47         Central City  1861-11-01
# 25     Grand County               49  Hot Sulphur Springs  1874-02-02
# 26  Gunnison County               51             Gunnison  1877-03-09
# 27  Hinsdale County               53            Lake City  1874-02-10
# 28  Huerfano County               55           Walsenburg  1861-11-01
# 29   Jackson County               57               Walden  1909-05-05
#
#                                        Formed from[8]  \
# 19                          Split from Summit County.
# ...

# %%
AI2={'DL':'Keras','ML':'SciPy','NA':'Netmiko','RPA':'Tkinter','DS':'Pandas','REST API':'Requests'}
AI2
# Out:
# {'DL': 'Keras',
#  'ML': 'SciPy',
#  'NA': 'Netmiko',
#  'RPA': 'Tkinter',
#  'DS': 'Pandas',
#  'REST API': 'Requests'}

# %%
AI3={'isim':['Erdeniz'],'soyisim':['Unvan']}
AI3
# Out:
# {'isim': ['Erdeniz'], 'soyisim': ['Unvan']}

# %%
DF10=pd.DataFrame.from_dict(AI3)
DF10
# Out:
#       isim soyisim
# 0  Erdeniz   Unvan

# %%
AI2={'DL':'Keras','ML':'SciPy','NA':'Netmiko','RPA':'Tkinter','DS':'Pandas','REST API':'Requests'}
AI2
# Out:
# {'DL': 'Keras',
#  'ML': 'SciPy',
#  'NA': 'Netmiko',
#  'RPA': 'Tkinter',
#  'DS': 'Pandas',
#  'REST API': 'Requests'}

# %%
DF11=pd.DataFrame.from_dict(AI2)
DF11
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-8061cac35472> in <cell line: 1>()
# ----> 1 DF11=pd.DataFrame.from_dict(AI2)
#       2 DF11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1762
#    1763         if orient != "tight":
# -> 1764             return cls(data, index=index, columns=columns, dtype=dtype)
#    1765         else:
#    1766             realdata = data["data"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
# ...

# %%
DF11=pd.DataFrame.from_dict(AI2,orient='index')
DF11
# Out:
#                  0
# DL           Keras
# ML           SciPy
# NA         Netmiko
# RPA        Tkinter
# DS          Pandas
# REST API  Requests

# %%
DF12=pd.DataFrame.from_dict(AI2,orient='index',columns=['Library'])
DF12
# Out:
#            Library
# DL           Keras
# ML           SciPy
# NA         Netmiko
# RPA        Tkinter
# DS          Pandas
# REST API  Requests

# %%
DF13=pd.DataFrame(AI2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-f4e041c0d563> in <cell line: 1>()
# ----> 1 DF13=pd.DataFrame(AI2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# ...

# %%
DF13=pd.DataFrame(AI2,index=['Library'])
DF13
# Out:
#             DL     ML       NA      RPA      DS  REST API
# Library  Keras  SciPy  Netmiko  Tkinter  Pandas  Requests

# %%
DF12
# Out:
#            Library
# DL           Keras
# ML           SciPy
# NA         Netmiko
# RPA        Tkinter
# DS          Pandas
# REST API  Requests

# %%
DF12_v2=DF12.T #Transpose: satiri sutuna ve sutunu satira: axis:0 satirlar, axis:1 sutun ve axis:1 sutunlar aynis sekilde axis:0 index olsun
DF12_v2
# Out:
#             DL     ML       NA      RPA      DS  REST API
# Library  Keras  SciPy  Netmiko  Tkinter  Pandas  Requests

# %%
DF13_v2= DF13.T
DF13_v2
# Out:
#            Library
# DL           Keras
# ML           SciPy
# NA         Netmiko
# RPA        Tkinter
# DS          Pandas
# REST API  Requests

# %%
#15:35 Kahve Molasi

# %%
import json

# %%
SW=json.load(open('starwars.json'))
SW[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-16b70678ffed> in <cell line: 1>()
# ----> 1 SW=json.load(open('starwars.json'))
#       2 SW[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'starwars.json'

# %%
len(SW)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-48e17230e58e> in <cell line: 1>()
# ----> 1 len(SW)
#
# NameError: name 'SW' is not defined

# %%
SW
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-6ffb1d2d206c> in <cell line: 1>()
# ----> 1 SW
#
# NameError: name 'SW' is not defined

# %%
# 'name': 'Luke Skywalker',
import json
SW=json.load(open('starwars.json'))
for karakter in SW:
    if karakter['name']=='Luke Skywalker':
        print(karakter['image'])
# Out:
# https://vignette.wikia.nocookie.net/starwars/images/2/20/LukeTLJ.jpg

# %%
SW_DF=pd.read_json('starwars.json')
SW_DF
# Out:
#     id            name  height   mass  gender  homeworld  \
# 0    1  Luke Skywalker    1.72   73.0    male   tatooine
# 1    2           C-3PO    1.71   75.0    male   tatooine
# 2    3           R2-D2    1.09   32.0    male      naboo
# 3    4     Darth Vader    2.03  120.0    male   tatooine
# 4    5     Leia Organa    1.50   51.0  female   alderaan
# ..  ..             ...     ...    ...     ...        ...
# 82  84            Finn    1.78   73.0    male        NaN
# 83  85             Rey    1.70   54.0  female      jakku
# 84  86     Poe Dameron    1.72   80.0    male    yavin 4
# 85  87             BB8    0.67   18.0    male        NaN
# 86  88  Captain Phasma    2.00   76.0  female  parnassos
#
#                                                wiki  \
# 0     http://starwars.wikia.com/wiki/Luke_Skywalker
# 1              http://starwars.wikia.com/wiki/C-3PO
# 2              http://starwars.wikia.com/wiki/R2-D2
# 3   http://starwars.wikia.com/wiki/Anakin_Skywalker
# ...

# %%
SW_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  87 non-null     int64
#  1   name                87 non-null     object
#  2   height              86 non-null     float64
#  3   mass                64 non-null     float64
#  4   gender              87 non-null     object
#  5   homeworld           81 non-null     object
#  6   wiki                87 non-null     object
#  7   image               87 non-null     object
#  8   born                47 non-null     object
#  9   bornLocation        6 non-null      object
#  10  died                47 non-null     float64
#  11  diedLocation        44 non-null     object
#  12  species             87 non-null     object
#  13  hairColor           48 non-null     object
#  14  eyeColor            87 non-null     object
# ...

# %%
SW_DF.isna()
# Out:
#        id   name  height   mass  gender  homeworld   wiki  image   born  \
# 0   False  False   False  False   False      False  False  False  False
# 1   False  False   False  False   False      False  False  False  False
# 2   False  False   False  False   False      False  False  False  False
# 3   False  False   False  False   False      False  False  False  False
# 4   False  False   False  False   False      False  False  False  False
# ..    ...    ...     ...    ...     ...        ...    ...    ...    ...
# 82  False  False   False  False   False       True  False  False  False
# 83  False  False   False  False   False      False  False  False  False
# 84  False  False   False  False   False      False  False  False  False
# 85  False  False   False  False   False       True  False  False   True
# 86  False  False   False  False   False      False  False  False   True
#
#     bornLocation  ...  model  class  sensorColor  platingColor  equipment  \
# ...

# %%
SW_DF.isna().sum()
# Out:
# id                     0
# name                   0
# height                 1
# mass                  23
# gender                 0
# homeworld              6
# wiki                   0
# image                  0
# born                  40
# bornLocation          81
# died                  40
# diedLocation          43
# species                0
# hairColor             39
# eyeColor               0
# skinColor              2
# cybernetics           81
# affiliations           0
# masters               72
# apprentices           75
# formerAffiliations     0
# dateCreated           86
# dateDestroyed         84
# destroyedLocation     84
# creator               86
# manufacturer          82
# model                 82
# class                 81
# sensorColor           82
# platingColor          81
# equipment             83
# productLine           84
# kajidic               86
# era                   84
# degree                86
# armament              85
# dtype: int64

# %%
SW_DF['homeworld']
# Out:
# 0      tatooine
# 1      tatooine
# 2         naboo
# 3      tatooine
# 4      alderaan
#         ...
# 82          NaN
# 83        jakku
# 84      yavin 4
# 85          NaN
# 86    parnassos
# Name: homeworld, Length: 87, dtype: object

# %%
#toplamda her degerden kac farkli adet var?
#value_counts
SW_DF['homeworld'].value_counts()
# Out:
# homeworld
# tatooine             11
# naboo                11
# coruscant             4
# alderaan              3
# kamino                3
# kashyyyk              2
# corellia              2
# ryloth                2
# mirial                2
# concord dawn          1
# iktotch               1
# quermia               1
# dorin                 1
# champala              1
# geonosis              1
# serenno               1
# ojom                  1
# zolan                 1
# glee anselm           1
# skako                 1
# scipio                1
# shili                 1
# kalee                 1
# umbara                1
# utapau                1
# jakku                 1
# yavin 4               1
# nar shaddaa           1
# troiken               1
# cerea                 1
# chandrila             1
# stewjon               1
# eriadu                1
# [Rodia, Tatooine]     1
# bestine               1
# trandosha             1
# socorro               1
# bespin                1
# ...

# %%
#adi luke skywalker olan kisinin image url'i
SW_DF['name']
# Out:
# 0     Luke Skywalker
# 1              C-3PO
# 2              R2-D2
# 3        Darth Vader
# 4        Leia Organa
#            ...
# 82              Finn
# 83               Rey
# 84       Poe Dameron
# 85               BB8
# 86    Captain Phasma
# Name: name, Length: 87, dtype: object

# %%
SW_DF['name']=='Luke Skywalker'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 82    False
# 83    False
# 84    False
# 85    False
# 86    False
# Name: name, Length: 87, dtype: bool

# %%
SW_DF[SW_DF['name']=='Luke Skywalker']
# Out:
#    id            name  height  mass gender homeworld  \
# 0   1  Luke Skywalker    1.72  73.0   male  tatooine
#
#                                             wiki  \
# 0  http://starwars.wikia.com/wiki/Luke_Skywalker
#
#                                                image born bornLocation  ...  \
# 0  https://vignette.wikia.nocookie.net/starwars/i...  -19  polis massa  ...
#
#    model class sensorColor platingColor equipment productLine kajidic  era  \
# 0    NaN   NaN         NaN          NaN       NaN         NaN     NaN  NaN
#
#   degree armament
# 0    NaN      NaN
#
# [1 rows x 36 columns]

# %%
import json
SW=json.load(open('starwars.json'))
for karakter in SW:
    if karakter['name']=='Luke Skywalker':
        print(karakter['masters'])
# Out:
# ['Obi-Wan Kenobi', 'Yoda']

# %%
SW_DF[SW_DF['name']=='Luke Skywalker']['masters']
# Out:
# 0    [Obi-Wan Kenobi, Yoda]
# Name: masters, dtype: object

# %%
#https://data.colorado.gov/resource/j5pc-4t32.json

# %%
import requests
url='https://data.colorado.gov/resource/j5pc-4t32.json'
response=requests.get(url)
response.json()
# Out:
# [{'station_name': 'BIGTOOTH RESERVOIR',
#   'div': '2',
#   'location': {'latitude': '38.829566',
#    'needs_recoding': False,
#    'longitude': '-104.971198'},
#   'dwr_abbrev': '1003668A',
#   'data_source': 'Co. Division of Water Resources',
#   ':@computed_region_nku6_53ud': '1447',
#   'station_type': 'Reservoir',
#   'wd': '10',
#   'http_linkage': {'url': 'https://dwr.state.co.us/Tools/Stations/1003668A'},
#   'date_time': '1999-09-30T00:00:00.000',
#   'county': 'EL PASO',
#   'variable': 'STORAGE',
#   'station_status': 'Active'},
#  {'station_name': 'ARF HEADGATE 49-D (HORSE CREEK)',
#   'div': '2',
#   'location': {'latitude': '38.092008',
#    'needs_recoding': False,
#    'longitude': '-103.350275'},
#   'dwr_abbrev': 'ARF049CO',
#   'data_source': 'Co. Division of Water Resources',
#   'amount': '14.30',
#   ':@computed_region_nku6_53ud': '84',
#   'station_type': 'Stream',
#   'wd': '17',
#   'http_linkage': {'url': 'https://dwr.state.co.us/Tools/Stations/ARF049CO'},
# ...

# %%
DF_col=pd.DataFrame(response.json())
DF_col
# Out:
#                                           station_name div  \
# 0                                   BIGTOOTH RESERVOIR   2
# 1                      ARF HEADGATE 49-D (HORSE CREEK)   2
# 2                                        PIONEER DITCH   1
# 3           DOUGLAS RESERVOIR AT SMITH RANCH NEAR RUSH   2
# 4                               UNITED #3 PUMP INLET 2   1
# ..                                                 ...  ..
# 995                                       HUDSON DITCH   2
# 996            IRONSTONE CANAL TAIL NEAR PEA GREEN, CO   4
# 997                         RYANS GULCH EXCHANGE DITCH   1
# 998   SOUTH FORK REPUBLICAN RIVER NEAR BENKELMAN, NEBR   1
# 999  IDAHO SPRINGS STORAGE RESERVOIR ABOVE IDAHO SP...   1
#
#                                               location dwr_abbrev  \
# 0    {'latitude': '38.829566', 'needs_recoding': Fa...   1003668A
# 1    {'latitude': '38.092008', 'needs_recoding': Fa...   ARF049CO
# ...

# %%
DF_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   station_name                 1000 non-null   object
#  1   div                          1000 non-null   object
#  2   location                     1000 non-null   object
#  3   dwr_abbrev                   1000 non-null   object
#  4   data_source                  1000 non-null   object
#  5   :@computed_region_nku6_53ud  1000 non-null   object
#  6   station_type                 1000 non-null   object
#  7   wd                           1000 non-null   object
#  8   http_linkage                 1000 non-null   object
#  9   date_time                    1000 non-null   object
#  10  county                       975 non-null    object
#  11  variable                     1000 non-null   object
#  12  station_status               1000 non-null   object
# ...

# %%
DF_col['station_name']
# Out:
# 0                                     BIGTOOTH RESERVOIR
# 1                        ARF HEADGATE 49-D (HORSE CREEK)
# 2                                          PIONEER DITCH
# 3             DOUGLAS RESERVOIR AT SMITH RANCH NEAR RUSH
# 4                                 UNITED #3 PUMP INLET 2
#                              ...
# 995                                         HUDSON DITCH
# 996              IRONSTONE CANAL TAIL NEAR PEA GREEN, CO
# 997                           RYANS GULCH EXCHANGE DITCH
# 998     SOUTH FORK REPUBLICAN RIVER NEAR BENKELMAN, NEBR
# 999    IDAHO SPRINGS STORAGE RESERVOIR ABOVE IDAHO SP...
# Name: station_name, Length: 1000, dtype: object

# %%
DF_col['amount']
# Out:
# 0         NaN
# 1       14.30
# 2        5.43
# 3        0.20
# 4        0.00
#         ...
# 995      3.94
# 996      4.18
# 997      5.36
# 998      0.00
# 999    224.00
# Name: amount, Length: 1000, dtype: object

# %%
SW_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  87 non-null     int64
#  1   name                87 non-null     object
#  2   height              86 non-null     float64
#  3   mass                64 non-null     float64
#  4   gender              87 non-null     object
#  5   homeworld           81 non-null     object
#  6   wiki                87 non-null     object
#  7   image               87 non-null     object
#  8   born                47 non-null     object
#  9   bornLocation        6 non-null      object
#  10  died                47 non-null     float64
#  11  diedLocation        44 non-null     object
#  12  species             87 non-null     object
#  13  hairColor           48 non-null     object
#  14  eyeColor            87 non-null     object
# ...

# %%
SW_DF['mass'].min()
# Out:
# 13.0

# %%
SW_DF['mass'].max()
# Out:
# 1358.0

# %%
SW_DF['mass'].sum()
# Out:
# 6066.2

# %%
#en kilolu karakterin adi
#en zayif karakterin adi

# %%
SW_DF[SW_DF['mass']==SW_DF['mass'].min()]
# Out:
#     id  name  height  mass gender homeworld  \
# 18  20  Yoda    0.66  13.0   male       NaN
#
#                                    wiki  \
# 18  http://starwars.wikia.com/wiki/Yoda
#
#                                                 image  born bornLocation  ...  \
# 18  https://vignette.wikia.nocookie.net/starwars/i...  -896          NaN  ...
#
#     model class sensorColor platingColor equipment productLine kajidic  era  \
# 18    NaN   NaN         NaN          NaN       NaN         NaN     NaN  NaN
#
#    degree armament
# 18    NaN      NaN
#
# [1 rows x 36 columns]

# %%
SW_DF[SW_DF['mass']==SW_DF['mass'].min()]['name']
# Out:
# 18    Yoda
# Name: name, dtype: object

# %%
SW_DF[SW_DF['mass']==SW_DF['mass'].max()]['name']
# Out:
# 15    Jabba Desilijic Tiure
# Name: name, dtype: object

# %%
DF_col['amount']
# Out:
# 0         NaN
# 1       14.30
# 2        5.43
# 3        0.20
# 4        0.00
#         ...
# 995      3.94
# 996      4.18
# 997      5.36
# 998      0.00
# 999    224.00
# Name: amount, Length: 1000, dtype: object

# %%
DF_col['amount'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 DF_col['amount'].sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11512, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11493 @doc(  # type: ignore[misc]
#   11494     _num_doc,
#   11495     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11510     **kwargs,
#   11511 ):
# > 11512     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11280, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11272 def sum(
#   11273     self,
#   11274     axis: Axis | None = None,
#    (...)
#   11278     **kwargs,
#   11279 ):
# > 11280     return self._min_count_stat_function(
# ...

# %%
#ben data frame'de tablomun sutunun veri tipini nasil degistircem
#numpy

# %%
import numpy as np

# %%
import random

# %%
data=random.random()
data
# Out:
# 0.16367552792840134

# %%
data1=random.randint(1,100)
data1
# Out:
# 17

# %%
data2=np.random.randn(4,2)
data2
# Out:
# array([[-1.43771233, -1.73677626],
#        [-1.69944943, -0.42614362],
#        [-1.21733467,  0.94967759],
#        [-0.37850343, -1.12352736]])

# %%
data2=np.random.randn(4,3)
data2
# Out:
# array([[ 0.92932623,  1.37916974,  1.01522825],
#        [-2.16094818, -0.69234657,  1.7831563 ],
#        [ 0.31562358,  1.1119184 ,  0.22019618],
#        [ 1.80401823,  0.10568016,  0.90386845]])

# %%
data2.dtype
# Out:
# dtype('float64')

# %%
#data2'yi int64 yap
data2_int=data2.astype('int64')
data2_int
# Out:
# array([[ 0,  1,  1],
#        [-2,  0,  1],
#        [ 0,  1,  0],
#        [ 1,  0,  0]], dtype=int64)

# %%
data2_int.dtype
# Out:
# dtype('int64')

# %%
data3=np.random.randint(50,100,size=(2,4))
data3
# Out:
# array([[72, 64, 59, 58],
#        [71, 83, 52, 65]])

# %%
data3.dtype
# Out:
# dtype('int32')

# %%
data3_float=data3.astype('float32')
data3_float
# Out:
# array([[72., 64., 59., 58.],
#        [71., 83., 52., 65.]], dtype=float32)

# %%
DF_col['amount']
# Out:
# 0         NaN
# 1       14.30
# 2        5.43
# 3        0.20
# 4        0.00
#         ...
# 995      3.94
# 996      4.18
# 997      5.36
# 998      0.00
# 999    224.00
# Name: amount, Length: 1000, dtype: object

# %%
DF_col['amount']=DF_col['amount'].astype('float32')
DF_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   station_name                 1000 non-null   object
#  1   div                          1000 non-null   object
#  2   location                     1000 non-null   object
#  3   dwr_abbrev                   1000 non-null   object
#  4   data_source                  1000 non-null   object
#  5   :@computed_region_nku6_53ud  1000 non-null   object
#  6   station_type                 1000 non-null   object
#  7   wd                           1000 non-null   object
#  8   http_linkage                 1000 non-null   object
#  9   date_time                    1000 non-null   object
#  10  county                       975 non-null    object
#  11  variable                     1000 non-null   object
#  12  station_status               1000 non-null   object
# ...

# %%
DF_col['amount']
# Out:
# 0         NaN
# 1       14.30
# 2        5.43
# 3        0.20
# 4        0.00
#         ...
# 995      3.94
# 996      4.18
# 997      5.36
# 998      0.00
# 999    224.00
# Name: amount, Length: 1000, dtype: float32

# %%
DF_col['amount'].sum()
# Out:
# 3441491.8

# %%
DF_col['amount'].min()
# Out:
# -999.0

# %%
DF_col['amount'].max()
# Out:
# 535202.0

# %%
SW_DF
# Out:
#     id            name  height   mass  gender  homeworld  \
# 0    1  Luke Skywalker    1.72   73.0    male   tatooine
# 1    2           C-3PO    1.71   75.0    male   tatooine
# 2    3           R2-D2    1.09   32.0    male      naboo
# 3    4     Darth Vader    2.03  120.0    male   tatooine
# 4    5     Leia Organa    1.50   51.0  female   alderaan
# ..  ..             ...     ...    ...     ...        ...
# 82  84            Finn    1.78   73.0    male        NaN
# 83  85             Rey    1.70   54.0  female      jakku
# 84  86     Poe Dameron    1.72   80.0    male    yavin 4
# 85  87             BB8    0.67   18.0    male        NaN
# 86  88  Captain Phasma    2.00   76.0  female  parnassos
#
#                                                wiki  \
# 0     http://starwars.wikia.com/wiki/Luke_Skywalker
# 1              http://starwars.wikia.com/wiki/C-3PO
# 2              http://starwars.wikia.com/wiki/R2-D2
# 3   http://starwars.wikia.com/wiki/Anakin_Skywalker
# ...

# %%
SW_DF.columns
# Out:
# Index(['id', 'name', 'height', 'mass', 'gender', 'homeworld', 'wiki', 'image',
#        'born', 'bornLocation', 'died', 'diedLocation', 'species', 'hairColor',
#        'eyeColor', 'skinColor', 'cybernetics', 'affiliations', 'masters',
#        'apprentices', 'formerAffiliations', 'dateCreated', 'dateDestroyed',
#        'destroyedLocation', 'creator', 'manufacturer', 'model', 'class',
#        'sensorColor', 'platingColor', 'equipment', 'productLine', 'kajidic',
#        'era', 'degree', 'armament'],
#       dtype='object')

# %%
len(SW_DF.columns)
# Out:
# 36

# %%
for column in SW_DF.columns:
    print(column)
# Out:
# id
# name
# height
# mass
# gender
# homeworld
# wiki
# image
# born
# bornLocation
# died
# diedLocation
# species
# hairColor
# eyeColor
# skinColor
# cybernetics
# affiliations
# masters
# apprentices
# formerAffiliations
# dateCreated
# dateDestroyed
# destroyedLocation
# creator
# manufacturer
# model
# class
# sensorColor
# platingColor
# equipment
# productLine
# kajidic
# era
# degree
# armament

# %%
SW_DF=SW_DF.drop(['skinColor', 'cybernetics', 'affiliations', 'masters'],axis=1)
len(SW_DF.columns)
# Out:
# 32

# %%
SW_DF.columns
# Out:
# Index(['id', 'name', 'height', 'mass', 'gender', 'homeworld', 'wiki', 'image',
#        'born', 'bornLocation', 'died', 'diedLocation', 'species', 'hairColor',
#        'eyeColor', 'apprentices', 'formerAffiliations', 'dateCreated',
#        'dateDestroyed', 'destroyedLocation', 'creator', 'manufacturer',
#        'model', 'class', 'sensorColor', 'platingColor', 'equipment',
#        'productLine', 'kajidic', 'era', 'degree', 'armament'],
#       dtype='object')

# %%
SW_DF=SW_DF.drop(columns=['eyeColor', 'apprentices', 'formerAffiliations', 'dateCreated'])
len(SW_DF.columns)
# Out:
# 28

# %%
SW_DF.columns
# Out:
# Index(['id', 'name', 'height', 'mass', 'gender', 'homeworld', 'wiki', 'image',
#        'born', 'bornLocation', 'died', 'diedLocation', 'species', 'hairColor',
#        'dateDestroyed', 'destroyedLocation', 'creator', 'manufacturer',
#        'model', 'class', 'sensorColor', 'platingColor', 'equipment',
#        'productLine', 'kajidic', 'era', 'degree', 'armament'],
#       dtype='object')
